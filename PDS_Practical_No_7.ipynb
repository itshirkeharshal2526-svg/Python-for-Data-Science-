# %% [markdown]
# **Python For Data Science**
#
#
# **Practical No 7**

# %% [markdown]
# **Roll No. : S036**
#
# **Name: HARSHAL SHIRKE**
#
# **Class : SYIT**
#
# **Batch : 1**
#
# **Date of Assignment : 02-09-2026**
#
# **Date/Time of Submission : 02-09-2026**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **a. Write a Python program to create a scatter plot of Age and Height of 5
# students.**

# %%
x = np.array([14,15,16,17,18])
y = np.array([150,160,170,180,190])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# **b. Write a Python program to create a bar chart showing marks of 5
# students.**

# %%
x = np.array(["A", "B", "C", "D","E"])
y = np.array([45,65,75,40,85])

plt.bar(x,y)
plt.show()

# %% [markdown]
# **c. Write a Python program to create a histogram showing the distribution of
# marks of 10 students.**

# %%
x = np.random.normal(45,65,85)
plt.hist(x)
plt.show()

# %% [markdown]
# **d. Write a Python program to create a pie chart showing the number of
# students in different courses.**

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["OPerating system", "Python", "PDS", "Hindi"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# **e. Write a Python program to create a bar chart showing sales of 5 different
# products.**

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()
